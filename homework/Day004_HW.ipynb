# %% [markdown]
# # 利用 Python 存取 API
#
#
# * 了解 Server Client 的架構與溝通方法
# * 知道 HTTP Request & Response 的內容
# * 什麼是 API？如何用 Python 程式存取 API 資料

# %% [markdown]
# ## 作業目標
#
# * 比較一下範例檔案中的「r.text」與「json.loads(r.text)」讀出來的內容有什麼差異
# * 自行尋找一個合適的 API 接口做練習，並且查看其回傳內容
#     * https://cat-fact.herokuapp.com/facts (來源：https://alexwohlbruck.github.io/cat-facts/)
#     * http://odata.wra.gov.tw/v4/RealtimeWaterLevel (來源：https://data.gov.tw/dataset/25768)

# %% [markdown]
# ### 比較一下範例檔案中的「r.text」與「json.loads(r.text)」讀出來的內容有什麼差異

# %%
import requests
r=requests.get('https://api.github.com/events')
r.text
# Out:
# '[{"id":"11175647316","type":"PushEvent","actor":{"id":28371483,"login":"bluerob45","display_login":"bluerob45","gravatar_id":"","url":"https://api.github.com/users/bluerob45","avatar_url":"https://avatars.githubusercontent.com/u/28371483?"},"repo":{"id":230825385,"name":"bluerob45/Aristotle","url":"https://api.github.com/repos/bluerob45/Aristotle"},"payload":{"push_id":4445186457,"size":1,"distinct_size":1,"ref":"refs/heads/master","head":"b448e7b5f40a9765e6dbec6f22af6c952e16d5f7","before":"0d8c16b5217dd1409de6ddbba0d8d8e2c3039332","commits":[{"sha":"b448e7b5f40a9765e6dbec6f22af6c952e16d5f7","author":{"email":"bluerob45@mailinator.com","name":"bluerob45"},"message":"GIT CloneShare Commit","distinct":true,"url":"https://api.github.com/repos/bluerob45/Aristotle/commits/b448e7b5f40a9765e6dbec6f22af6c952e16d5f7"}]},"public":true,"created_at":"2019-12-30T02:48:49Z"},{"id":"11175647314","type":"CreateEvent","actor":{"id":49699333,"login":"dependabot[bot]","display_login":"dependabot","gravatar_id":"","url":"https://api.github.com/users/dependabot[bot]","avatar_url":"https://avatars.githubusercontent.com/u/49699333?"},"repo":{"id":212974155,"name":"singhmanmeetsingh/reactTodo","url":"https://api.github.com/repos/singhmanmeetsingh/reactTodo"},"payload":{"ref":"dependabot/npm_and_yarn/handlebars-4.5.3","ref_type":"branch","master_branch":"master","description":null,"pusher_type":"user"},"public":true,"created_at":"2019-12-30T02:48:49Z"},{"id":"11175647310","type":"PushEvent","actor":{"id":11974795,"login":"knowsuchagency","display_login":"knowsuchagency","gravatar_id":"","url":"https://api.github.com/users/knowsuchagency","avatar_url":"https://avatars.githubusercontent.com/u/11974795?"},"repo":{"id":170247959,"name":"knowsuchagency/klaxon","url":"https://api.github.com/repos/knowsuchagency/klaxon"},"payload":{"push_id":4445186453,"size":1,"distinct_size":1,"ref":"refs/heads/master","head":"f92e2b4f743fe52ca25bef6a919f2517ce4e7e4e","before":"0a463de57b646f0dbd0f6479c4222cd1737778a5","commits":[{"sha":"f92e2b4f743fe52ca25bef6a919f2517ce4e7e4e","author":{"email":"knowsuchagency@gmail.com","name":"Stephan Fitzpatrick"},"message":"optimize imports","distinct":true,"url":"https://api.github.com/repos/knowsuchagency/klaxon/commits/f92e2b4f743fe52ca25bef6a919f2517ce4e7e4e"}]},"public":true,"created_at":"2019-12-30T02:48:49Z"},{"id":"11175647304","type":"WatchEvent","actor":{"id":5318189,"login":"Junw","display_login":"Junw","gravatar_id":"","url":"https://api.github.com/users/Junw","avatar_url":"https://avatars.githubusercontent.com/u/5318189?"},"repo":{"id":41986369,"name":"pingcap/tidb","url":"https://api.github.com/repos/pingcap/tidb"},"payload":{"action":"started"},"public":true,"created_at":"2019-12-30T02:48:49Z","org":{"id":11855343,"login":"pingcap","gravatar_id":"","url":"https://api.github.com/orgs/pingcap","avatar_url":"https://avatars.githubusercontent.com/u/11855343?"}},{"id":"11175647301","type":"ForkEvent","actor":{"id":11769016,"login":"tranminhtan","display_login":"tranminhtan","gravatar_id":"","url":"https://api.github.com/users/tranminhtan","avatar_url":"https://avatars.githubusercontent.com/u/11769016?"},"repo":{"id":11495787,"name":"JakeWharton/timber","url":"https://api.github.com/repos/JakeWharton/timber"},"payload":{"forkee":{"id":230835788,"node_id":"MDEwOlJlcG9zaXRvcnkyMzA4MzU3ODg=","name":"timber","full_name":"tranminhtan/timber","private":false,"owner":{"login":"tranminhtan","id":11769016,"node_id":"MDQ6VXNlcjExNzY5MDE2","avatar_url":"https://avatars2.githubusercontent.com/u/11769016?v=4","gravatar_id":"","url":"https://api.github.com/users/tranminhtan","html_url":"https://github.com/tranminhtan","followers_url":"https://api.github.com/users/tranminhtan/followers","following_url":"https://api.github.com/users/tranminhtan/following{/other_user}","gists_url":"https://api.github.com/users/tranminhtan/gists{/gist_id}","starred_url":"https://api.github.com/users/tranminhtan/starred{/owner}{/repo}","subscriptions_url":"ht ...

# %%
import json
json.loads(r.text)
# Out:
# [{'id': '11175647316',
#   'type': 'PushEvent',
#   'actor': {'id': 28371483,
#    'login': 'bluerob45',
#    'display_login': 'bluerob45',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/bluerob45',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/28371483?'},
#   'repo': {'id': 230825385,
#    'name': 'bluerob45/Aristotle',
#    'url': 'https://api.github.com/repos/bluerob45/Aristotle'},
#   'payload': {'push_id': 4445186457,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'b448e7b5f40a9765e6dbec6f22af6c952e16d5f7',
#    'before': '0d8c16b5217dd1409de6ddbba0d8d8e2c3039332',
#    'commits': [{'sha': 'b448e7b5f40a9765e6dbec6f22af6c952e16d5f7',
#      'author': {'email': 'bluerob45@mailinator.com', 'name': 'bluerob45'},
#      'message': 'GIT CloneShare Commit',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/bluerob45/Aristotle/commits/b448e7b5f40a9765e6dbec6f22af6c952e16d5f7'}]},
#   'public': True,
#   'created_at': '2019-12-30T02:48:49Z'},
#  {'id': '11175647314',
#   'type': 'CreateEvent',
#   'actor': {'id': 49699333,
#    'login': 'dependabot[bot]',
#    'display_login': 'dependabot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dependabot[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/49699333?'},
#   'repo': {'id': 212974155,
#    'name': 'singhmanmeetsingh/reactTodo',
#    'url': 'https://api.github.com/repos/singhmanmeetsingh/reactTodo'},
#   'payload': {'ref': 'dependabot/npm_and_yarn/handlebars-4.5.3',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2019-12-30T02:48:49Z'},
#  {'id': '11175647310',
#   'type': 'PushEvent',
#   'actor': {'id': 11974795,
#    'login': 'knowsuchagency',
#    'display_login': 'knowsuchagency',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/knowsuchagency',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/11974795?'},
#   'repo': {'id': 170247959,
#    'name': 'knowsuchagency/klaxon',
#    'url': 'https://api.github.com/repos/knowsuchagency/klaxon'},
#   'payload': {'push_id': 4445186453,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'f92e2b4f743fe52ca25bef6a919f2517ce4e7e4e',
#    'before': '0a463de57b646f0dbd0f6479c4222cd1737778a5',
#    'commits': [{'sha': 'f92e2b4f743fe52ca25bef6a919f2517ce4e7e4e',
#      'author': {'email': 'knowsuchagency@gmail.com',
#       'name': 'Stephan Fitzpatrick'},
#      'message': 'optimize imports',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/knowsuchagency/klaxon/commits/f92e2b4f743fe52ca25bef6a919f2517ce4e7e4e'}]},
#   'public': True,
#   'created_at': '2019-12-30T02:48:49Z'},
#  {'id': '11175647304',
#   'type': 'WatchEvent',
#   'actor': {'id': 5318189,
#    'login': 'Junw',
#    'display_login': 'Junw',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Junw',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/5318189?'},
#   'repo': {'id': 41986369,
#    'name': 'pingcap/tidb',
#    'url': 'https://api.github.com/repos/pingcap/tidb'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2019-12-30T02:48:49Z',
#   'org': {'id': 11855343,
#    'login': 'pingcap',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/pingcap',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/11855343?'}},
#  {'id': '11175647301',
#   'type': 'ForkEvent',
#   'actor': {'id': 11769016,
#    'login': 'tranminhtan',
#    'display_login': 'tranminhtan',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/tranminhtan',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/11769016?'},
#   'repo': {'id': 11495787,
#    'name': 'JakeWharton/timber',
#    'url': 'https://api.github.com/repos/JakeWharton/timber'},
#   'payload': {'forkee': {'id': 230835788,
#     'node_id': 'MDEwOlJlcG9zaXRvcnkyMzA4MzU3ODg=',
#     'name': 'timber',
#     'full_name': 'tranminhtan/timber',
#     'private': False,
#     'owner': {'login': 'tranminhtan',
#      'id': 11769016,
#      'node_id': 'MDQ6VXNlcjExNzY5MDE2',
#      'avatar_url': 'https://avatars2.githubusercontent.com/u/11769016?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/tranminhtan',
#      'html_url': 'https://github.com/tranminhtan',
#      'followers_url': 'https://api.github.com/users/tranminhtan/followers',
#      'following_url': 'https://api.github.com/users/tranminhtan/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/tranminhtan/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/tranminhtan/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/tranminhtan/subscriptions',
#      'organizations_url': 'https://api.github.com/users/tranminhtan/orgs',
#      'repos_url': 'https://api.github.com/users/tranminhtan/repos',
#      'events_url': 'https://api.github.com/users/tranminhtan/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/tranminhtan/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'html_url': 'https://github.com/tranminhtan/timber',
#     'description': "A logger with a small, extensible API which provides utility on top of Android's normal Log class.",
#     'fork': True,
#     'url': 'https://api.github.com/repos/tranminhtan/timber',
#     'forks_url': 'https://api.github.com/repos/tranminhtan/timber/forks',
#     'keys_url': 'https://api.github.com/repos/tranminhtan/timber/keys{/key_id}',
#     'collaborators_url': 'https://api.github.com/repos/tranminhtan/timber/collaborators{/collaborator}',
#     'teams_url': 'https://api.github.com/repos/tranminhtan/timber/teams',
#     'hooks_url': 'https://api.github.com/repos/tranminhtan/timber/hooks',
#     'issue_events_url': 'https://api.github.com/repos/tranminhtan/timber/issues/events{/number}',
#     'events_url': 'https://api.github.com/repos/tranminhtan/timber/events',
#     'assignees_url': 'https://api.github.com/repos/tranminhtan/timber/assignees{/user}',
#     'branches_url': 'https://api.github.com/repos/tranminhtan/timber/branches{/branch}',
#     'tags_url': 'https://api.github.com/repos/tranminhtan/timber/tags',
#     'blobs_url': 'https://api.github.com/repos/tranminhtan/timber/git/blobs{/sha}',
#     'git_tags_url': 'https://api.github.com/repos/tranminhtan/timber/git/tags{/sha}',
#     'git_refs_url': 'https://api.github.com/repos/tranminhtan/timber/git/refs{/sha}',
#     'trees_url': 'https://api.github.com/repos/tranminhtan/timber/git/trees{/sha}',
#     'statuses_url': 'https://api.github.com/repos/tranminhtan/timber/statuses/{sha}',
#     'languages_url': 'https://api.github.com/repos/tranminhtan/timber/languages',
#     'stargazers_url': 'https://api.github.com/repos/tranminhtan/timber/stargazers',
#     'contributors_url': 'https://api.github.com/repos/tranminhtan/timber/contributors',
#     'subscribers_url': 'https://api.github.com/repos/tranminhtan/timber/subscribers',
#     'subscription_url': 'https://api.github.com/repos/tranminhtan/timber/subscription',
#     'commits_url': 'https://api.github.com/repos/tranminhtan/timber/commits{/sha}',
#     'git_commits_url': 'https://api.github.com/repos/tranminhtan/timber/git/commits{/sha}',
#     'comments_url': 'https://api.github.com/repos/tranminhtan/timber/comments{/number}',
#     'issue_comment_url': 'https://api.github.com/repos/tranminhtan/timber/issues/comments{/number}',
#     'contents_url': 'https://api.github.com/repos/tranminhtan/timber/contents/{+path}',
#     'compare_url': 'https://api.github.com/repos/tranminhtan/timber/compare/{base}...{head}',
#     'merges_url': 'https://api.github.com/repos/tranminhtan/timber/merges',
#     'archive_url': 'https://api.github.com/repos/tranminhtan/timber/{archive_format}{/ref}',
#     'downloads_url': 'https://api.github.com/repos/tranminhtan/timber/downloads',
#     'issues_url': 'https://api.github.com/repos/tranminhtan/timber/issues{/number}',
#     'pulls_url': 'https://api.github.com/repos/tranminhtan/timber/pulls{/number}',
#     'milestones_url': 'https://api.github.com/repos/tranminhtan/timber/milestones{/number}',
#     'notifications_url': 'https://api.github.com/repos/tranminhtan/timber/notifications{?since,all,participating}',
#     'labels_url': 'https://api.github.com/repos/tranminhtan/timber/labels{/name}',
#     'releases_url': 'https://api.github.com/repos/tranminhtan/timber/releases{/id}',
#     'deployments_url': 'https://api.github.com/repos/tranminhtan/timber/deployments',
#     'created_at': '2019-12-30T02:48:48Z',
#     'updated_at': '2019-12-27T16:25:46Z',
#     'pushed_at': '2019-12-10T03:58:45Z',
#     'git_url': 'git://github.com/tranminhtan/timber.git',
#     'ssh_url': 'git@github.com:tranminhtan/timber.git',
#     'clone_url': 'https://github.com/tranminhtan/timber.git',
#     'svn_url': 'https://github.com/tranminhtan/timber',
#     'homepage': 'http://jakewharton.github.io/timber/',
#     'size': 1290,
#     'stargazers_count': 0,
#     'watchers_count': 0,
#     'language': None,
#     'has_issues': False,
#     'has_projects': True,
#     'has_downloads': True,
#     'has_wiki': False,
#     'has_pages': False,
#     'forks_count': 0,
#     'mirror_url': None,
#     'archived': False,
#     'disabled': False,
#     'open_issues_count': 0,
#     'license': None,
#     'forks': 0,
#     'open_issues': 0,
#     'watchers': 0,
#     'default_branch': 'master',
#     'public': True}},
#   'public': True,
#   'created_at': '2019-12-30T02:48:49Z'},
#  {'id': '11175647300',
#   'type': 'WatchEvent',
#   'actor': {'id': 29426156,
#    'login': 'leeory',
#    'display_login': 'leeory',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/leeory',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/29426156?'},
#   'repo': {'id': 209921402,
#    'name': 'newbee-ltd/newbee-mall',
#    'url': 'https://api.github.com/repos/newbee-ltd/newbee-mall'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2019-12-30T02:48:49Z',
#   'org': {'id': 54432684,
#    'login': 'newbee-ltd',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/newbee-ltd',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/54432684?'}},
#  {'id': '11175647297',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 49699333,
#    'login': 'dependabot[bot]',
#    'display_login': 'dependabot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dependabot[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/49699333?'},
#   'repo': {'id': 212865507,
#    'name': 'VitorPiovezan/Projeto_GameOn',
#    'url': 'https://api.github.com/repos/VitorPiovezan/Projeto_GameOn'},
#   'payload': {'action': 'opened',
#    'number': 2,
#    'pull_request': {'url': 'https://api.github.com/repos/VitorPiovezan/Projeto_GameOn/pulls/2',
#     'id': 357952003,
#     'node_id': 'MDExOlB1bGxSZXF1ZXN0MzU3OTUyMDAz',
#     'html_url': 'https://github.com/VitorPiovezan/Projeto_GameOn/pull/2',
#     'diff_url': 'https://github.com/VitorPiovezan/Projeto_GameOn/pull/2.diff',
#     'patch_url': 'https://github.com/VitorPiovezan/Projeto_GameOn/pull/2.patch',
#     'issue_url': 'https://api.github.com/repos/VitorPiovezan/Projeto_GameOn/issues/2',
#     'number': 2,
#     'state': 'open',
#     'locked': False,
#     'title': 'Bump handlebars from 4.1.2 to 4.5.3 in /frontend',
#     'user': {'login': 'dependabot[bot]',
#      'id': 49699333,
#      'node_id': 'MDM6Qm90NDk2OTkzMzM=',
#      'avatar_url': 'https://avatars0.githubusercontent.com/in/29110?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/dependabot%5Bbot%5D',
#      'html_url': 'https://github.com/apps/dependabot',
#      'followers_url': 'https://api.github.com/users/dependabot%5Bbot%5D/followers',
#      'following_url': 'https://api.github.com/users/dependabot%5Bbot%5D/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/dependabot%5Bbot%5D/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/dependabot%5Bbot%5D/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/dependabot%5Bbot%5D/subscriptions',
#      'organizations_url': 'https://api.github.com/users/dependabot%5Bbot%5D/orgs',
#      'repos_url': 'https://api.github.com/users/dependabot%5Bbot%5D/repos',
#      'events_url': 'https://api.github.com/users/dependabot%5Bbot%5D/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/dependabot%5Bbot%5D/received_events',
#      'type': 'Bot',
#      'site_admin': False},
#     'body': 'Bumps [handlebars](https://github.com/wycats/handlebars.js) from 4.1.2 to 4.5.3.\n<details>\n<summary>Changelog</summary>\n\n*Sourced from [handlebars\'s changelog](https://github.com/wycats/handlebars.js/blob/master/release-notes.md).*\n\n> ## v4.5.3 - November 18th, 2019\n> Bugfixes:\n> \n> - fix: add "no-prototype-builtins" eslint-rule and fix all occurences - f7f05d7\n> - fix: add more properties required to be enumerable - 1988878\n> \n> Chores / Build:\n> - fix: use !== 0 instead of != 0 - c02b05f\n> - add chai and dirty-chai and sinon, for cleaner test-assertions and spies, \n>   deprecate old assertion-methods  - 93e284e, 886ba86, 0817dad, 93516a0\n> \n> Security:\n> \n> - The properties `__proto__`, `__defineGetter__`, `__defineSetter__` and `__lookupGetter__` \n>   have been added to the list of "properties that must be enumerable".\n>   If a property by that name is found and not enumerable on its parent, \n>   it will silently evaluate to `undefined`. This is done in both the compiled template and the "lookup"-helper. \n>   This will prevent new Remote-Code-Execution exploits that have been\n>   published recently.\n> \n> Compatibility notes: \n> \n> - Due to the security-fixes. The semantics of the templates using\n>   `__proto__`, `__defineGetter__`, `__defineSetter__` and `__lookupGetter__` in the respect that those expression now return \n>   `undefined` rather than their actual value from the proto.\n> - The semantics have not changed in cases where the properties are  enumerable, as in:\n> \n> ```js\n> {\n>   __proto__: \'some string\'\n> }\n> ```\n> \n> - The change may be breaking in that respect, but we still only \n>   increase the patch-version, because the incompatible use-cases\n>   are not intended, undocumented and far less important than fixing\n>   Remote-Code-Execution exploits on existing systems.\n> \n> \n> \n> [Commits](https://github.com/wycats/handlebars.js/compare/v4.5.2...v4.5.3)\n> \n> ## v4.5.2 - November 13th, 2019\n> # Bugfixes\n> \n> - fix: use String(field) in lookup when checking for "constructor" - d541378\n> - test: add fluent API for testing Handlebars - c2ac79c\n> \n> Compatibility notes:\n> - no incompatibility are to be expected\n></tr></table> ... (truncated)\n</details>\n<details>\n<summary>Commits</summary>\n\n- [`c819c8b`](https://github.com/wycats/handlebars.js/commit/c819c8b533934d2ac18001d7eb27a3205b00c2f3) v4.5.3\n- [`827c9d0`](https://github.com/wycats/handlebars.js/commit/827c9d0747bef7d7f89829779523b6b2dcf3051d) Update release notes\n- [`f7f05d7`](https://github.com/wycats/handlebars.js/commit/f7f05d7558e674856686b62a00cde5758f3b7a08) fix: add "no-prototype-builtins" eslint-rule and fix all occurences\n- [`1988878`](https://github.com/wycats/handlebars.js/commit/198887808780bbef9dba67a8af68ece091d5baa7) fix: add more properties required to be enumerable\n- [`886ba86`](https://github.com/wycats/handlebars.js/commit/886ba86c2f9cc71b7d99b9018fbe2d72a57085cc) test/chore: add chai/expect and sinon to "runtime"-environment\n- [`0817dad`](https://github.com/wycats/handlebars.js/commit/0817dad7e72c51d07f7700547d0c69aa79a4976b) test: add sinon as global variable to eslint in the specs\n- [`93516a0`](https://github.com/wycats/handlebars.js/commit/93516a0b07026ebd23c84fddf270a0c8b570bc59) test: add sinon.js for spies, deprecate current assertions\n- [`93e284e`](https://github.com/wycats/handlebars.js/commit/93e284ed9be1e38c5e6945f15af1ccd689f2ada6) chore: add chai and dirty-chai for better test assertions\n- [`c02b05f`](https://github.com/wycats/handlebars.js/commit/c02b05fa819f46bb66c878bebc6e8006408ebd5c) fix: use !== 0 instead of != 0\n- [`8de121d`](https://github.com/wycats/handlebars.js/commit/8de121d21c88a6ab877e3a0eec9daaac483f3bf0) v4.5.2\n- Additional commits viewable in [compare view](https://github.com/wycats/handlebars.js/compare/v4.1.2...v4.5.3)\n</details>\n<br />\n\n[![Dependabot compatibility score](https://dependabot-badges.githubapp.com/badges/com ...
#     'created_at': '2019-12-30T02:48:48Z',
#     'updated_at': '2019-12-30T02:48:48Z',
#     'closed_at': None,
#     'merged_at': None,
#     'merge_commit_sha': None,
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [],
#     'milestone': None,
#     'commits_url': 'https://api.github.com/repos/VitorPiovezan/Projeto_GameOn/pulls/2/commits',
#     'review_comments_url': 'https://api.github.com/repos/VitorPiovezan/Projeto_GameOn/pulls/2/comments',
#     'review_comment_url': 'https://api.github.com/repos/VitorPiovezan/Projeto_GameOn/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/VitorPiovezan/Projeto_GameOn/issues/2/comments',
#     'statuses_url': 'https://api.github.com/repos/VitorPiovezan/Projeto_GameOn/statuses/edcb623a234b2d948ac2fe1e48f3a0c1ffe5cb56',
#     'head': {'label': 'VitorPiovezan:dependabot/npm_and_yarn/frontend/handlebars-4.5.3',
#      'ref': 'dependabot/npm_and_yarn/frontend/handlebars-4.5.3',
#      'sha': 'edcb623a234b2d948ac2fe1e48f3a0c1ffe5cb56',
#      'user': {'login': 'VitorPiovezan',
#       'id': 56170034,
#       'node_id': 'MDQ6VXNlcjU2MTcwMDM0',
#       'avatar_url': 'https://avatars2.githubusercontent.com/u/56170034?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/VitorPiovezan',
#       'html_url': 'https://github.com/VitorPiovezan',
#       'followers_url': 'https://api.github.com/users/VitorPiovezan/followers',
#       'following_url': 'https://api.github.com/users/VitorPiovezan/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/VitorPiovezan/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/VitorPiovezan/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/VitorPiovezan/subscriptions',
#       'organizations_url': 'https://api.github.com/users/VitorPiovezan/orgs',
#       'repos_url': 'https://api.github.com/users/VitorPiovezan/repos',
#       'events_url': 'https://api.github.com/users/VitorPiovezan/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/VitorPiovezan/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 212865507,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkyMTI4NjU1MDc=',
#       'name': 'Projeto_GameOn',
#       'full_name': 'VitorPiovezan/Projeto_GameOn',
#       'private': False,
#       'owner': {'login': 'VitorPiovezan',
#        'id': 56170034,
#        'node_id': 'MDQ6VXNlcjU2MTcwMDM0',
#        'avatar_url': 'https://avatars2.githubusercontent.com/u/56170034?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/VitorPiovezan',
#        'html_url': 'https://github.com/VitorPiovezan',
#        'followers_url': 'https://api.github.com/users/VitorPiovezan/followers',
#        'following_url': 'https://api.github.com/users/VitorPiovezan/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/VitorPiovezan/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/VitorPiovezan/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/VitorPiovezan/subscriptions',
#        'organizations_url': 'https://api.github.com/users/VitorPiovezan/orgs',
#        'repos_url': 'https://api.github.com/users/VitorPiovezan/repos',
#        'events_url': 'https://api.github.com/users/VitorPiovezan/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/VitorPiovezan/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/VitorPiovezan/Projeto_GameOn',
#       'description': None,
#       'fork': False,
#       'url': 'https://api.github.com/repos/VitorPiovezan/Projeto_GameOn',
#       'forks_url': 'https://api.github.com/repos/VitorPiovezan/Projeto_GameOn/forks',
#       'keys_url': 'https://api.github.com/repos/VitorPiovezan/Projeto_GameOn/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/VitorPiovezan/Projeto_GameOn/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/VitorPiovezan/Projeto_GameOn/teams',
#       'hooks_url': 'https://api.github.com/repos/VitorPiovezan/Projeto_GameOn/hooks',
#       'issue_events_url': 'https://api.github.com/repos/VitorPiovezan/Projeto_GameOn/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/VitorPiovezan/Projeto_GameOn/events',
#       'assignees_url': 'https://api.github.com/repos/VitorPiovezan/Projeto_GameOn/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/VitorPiovezan/Projeto_GameOn/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/VitorPiovezan/Projeto_GameOn/tags',
#       'blobs_url': 'https://api.github.com/repos/VitorPiovezan/Projeto_GameOn/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/VitorPiovezan/Projeto_GameOn/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/VitorPiovezan/Projeto_GameOn/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/VitorPiovezan/Projeto_GameOn/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/VitorPiovezan/Projeto_GameOn/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/VitorPiovezan/Projeto_GameOn/languages',
#       'stargazers_url': 'https://api.github.com/repos/VitorPiovezan/Projeto_GameOn/stargazers',
#       'contributors_url': 'https://api.github.com/repos/VitorPiovezan/Projeto_GameOn/contributors',
#       'subscribers_url': 'https://api.github.com/repos/VitorPiovezan/Projeto_GameOn/subscribers',
#       'subscription_url': 'https://api.github.com/repos/VitorPiovezan/Projeto_GameOn/subscription',
#       'commits_url': 'https://api.github.com/repos/VitorPiovezan/Projeto_GameOn/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/VitorPiovezan/Projeto_GameOn/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/VitorPiovezan/Projeto_GameOn/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/VitorPiovezan/Projeto_GameOn/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/VitorPiovezan/Projeto_GameOn/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/VitorPiovezan/Projeto_GameOn/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/VitorPiovezan/Projeto_GameOn/merges',
#       'archive_url': 'https://api.github.com/repos/VitorPiovezan/Projeto_GameOn/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/VitorPiovezan/Projeto_GameOn/downloads',
#       'issues_url': 'https://api.github.com/repos/VitorPiovezan/Projeto_GameOn/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/VitorPiovezan/Projeto_GameOn/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/VitorPiovezan/Projeto_GameOn/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/VitorPiovezan/Projeto_GameOn/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/VitorPiovezan/Projeto_GameOn/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/VitorPiovezan/Projeto_GameOn/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/VitorPiovezan/Projeto_GameOn/deployments',
#       'created_at': '2019-10-04T17:09:32Z',
#       'updated_at': '2019-10-11T02:34:48Z',
#       'pushed_at': '2019-12-30T02:48:47Z',
#       'git_url': 'git://github.com/VitorPiovezan/Projeto_GameOn.git',
#       'ssh_url': 'git@github.com:VitorPiovezan/Projeto_GameOn.git',
#       'clone_url': 'https://github.com/VitorPiovezan/Projeto_GameOn.git',
#       'svn_url': 'https://github.com/VitorPiovezan/Projeto_GameOn',
#       'homepage': None,
#       'size': 7741,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'JavaScript',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 2,
#       'license': None,
#       'forks': 0,
#       'open_issues': 2,
#       'watchers': 0,
#       'default_branch': 'master'}},
#     'base': {'label': 'VitorPiovezan:master',
#      'ref': 'master',
#      'sha': '4ccc541b23c96cf33ff1e10f688cf01d97e21d23',
#      'user': {'login': 'VitorPiovezan',
#       'id': 56170034,
#       'node_id': 'MDQ6VXNlcjU2MTcwMDM0',
#       'avatar_url': 'https://avatars2.githubusercontent.com/u/56170034?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/VitorPiovezan',
#       'html_url': 'https://github.com/VitorPiovezan',
#       'followers_url': 'https://api.github.com/users/VitorPiovezan/followers',
#       'following_url': 'https://api.github.com/users/VitorPiovezan/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/VitorPiovezan/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/VitorPiovezan/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/VitorPiovezan/subscriptions',
#       'organizations_url': 'https://api.github.com/users/VitorPiovezan/orgs',
#       'repos_url': 'https://api.github.com/users/VitorPiovezan/repos',
#       'events_url': 'https://api.github.com/users/VitorPiovezan/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/VitorPiovezan/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 212865507,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkyMTI4NjU1MDc=',
#       'name': 'Projeto_GameOn',
#       'full_name': 'VitorPiovezan/Projeto_GameOn',
#       'private': False,
#       'owner': {'login': 'VitorPiovezan',
#        'id': 56170034,
#        'node_id': 'MDQ6VXNlcjU2MTcwMDM0',
#        'avatar_url': 'https://avatars2.githubusercontent.com/u/56170034?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/VitorPiovezan',
#        'html_url': 'https://github.com/VitorPiovezan',
#        'followers_url': 'https://api.github.com/users/VitorPiovezan/followers',
#        'following_url': 'https://api.github.com/users/VitorPiovezan/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/VitorPiovezan/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/VitorPiovezan/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/VitorPiovezan/subscriptions',
#        'organizations_url': 'https://api.github.com/users/VitorPiovezan/orgs',
#        'repos_url': 'https://api.github.com/users/VitorPiovezan/repos',
#        'events_url': 'https://api.github.com/users/VitorPiovezan/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/VitorPiovezan/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/VitorPiovezan/Projeto_GameOn',
#       'description': None,
#       'fork': False,
#       'url': 'https://api.github.com/repos/VitorPiovezan/Projeto_GameOn',
#       'forks_url': 'https://api.github.com/repos/VitorPiovezan/Projeto_GameOn/forks',
#       'keys_url': 'https://api.github.com/repos/VitorPiovezan/Projeto_GameOn/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/VitorPiovezan/Projeto_GameOn/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/VitorPiovezan/Projeto_GameOn/teams',
#       'hooks_url': 'https://api.github.com/repos/VitorPiovezan/Projeto_GameOn/hooks',
#       'issue_events_url': 'https://api.github.com/repos/VitorPiovezan/Projeto_GameOn/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/VitorPiovezan/Projeto_GameOn/events',
#       'assignees_url': 'https://api.github.com/repos/VitorPiovezan/Projeto_GameOn/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/VitorPiovezan/Projeto_GameOn/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/VitorPiovezan/Projeto_GameOn/tags',
#       'blobs_url': 'https://api.github.com/repos/VitorPiovezan/Projeto_GameOn/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/VitorPiovezan/Projeto_GameOn/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/VitorPiovezan/Projeto_GameOn/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/VitorPiovezan/Projeto_GameOn/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/VitorPiovezan/Projeto_GameOn/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/VitorPiovezan/Projeto_GameOn/languages',
#       'stargazers_url': 'https://api.github.com/repos/VitorPiovezan/Projeto_GameOn/stargazers',
#       'contributors_url': 'https://api.github.com/repos/VitorPiovezan/Projeto_GameOn/contributors',
#       'subscribers_url': 'https://api.github.com/repos/VitorPiovezan/Projeto_GameOn/subscribers',
#       'subscription_url': 'https://api.github.com/repos/VitorPiovezan/Projeto_GameOn/subscription',
#       'commits_url': 'https://api.github.com/repos/VitorPiovezan/Projeto_GameOn/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/VitorPiovezan/Projeto_GameOn/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/VitorPiovezan/Projeto_GameOn/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/VitorPiovezan/Projeto_GameOn/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/VitorPiovezan/Projeto_GameOn/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/VitorPiovezan/Projeto_GameOn/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/VitorPiovezan/Projeto_GameOn/merges',
#       'archive_url': 'https://api.github.com/repos/VitorPiovezan/Projeto_GameOn/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/VitorPiovezan/Projeto_GameOn/downloads',
#       'issues_url': 'https://api.github.com/repos/VitorPiovezan/Projeto_GameOn/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/VitorPiovezan/Projeto_GameOn/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/VitorPiovezan/Projeto_GameOn/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/VitorPiovezan/Projeto_GameOn/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/VitorPiovezan/Projeto_GameOn/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/VitorPiovezan/Projeto_GameOn/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/VitorPiovezan/Projeto_GameOn/deployments',
#       'created_at': '2019-10-04T17:09:32Z',
#       'updated_at': '2019-10-11T02:34:48Z',
#       'pushed_at': '2019-12-30T02:48:47Z',
#       'git_url': 'git://github.com/VitorPiovezan/Projeto_GameOn.git',
#       'ssh_url': 'git@github.com:VitorPiovezan/Projeto_GameOn.git',
#       'clone_url': 'https://github.com/VitorPiovezan/Projeto_GameOn.git',
#       'svn_url': 'https://github.com/VitorPiovezan/Projeto_GameOn',
#       'homepage': None,
#       'size': 7741,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'JavaScript',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 2,
#       'license': None,
#       'forks': 0,
#       'open_issues': 2,
#       'watchers': 0,
#       'default_branch': 'master'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/VitorPiovezan/Projeto_GameOn/pulls/2'},
#      'html': {'href': 'https://github.com/VitorPiovezan/Projeto_GameOn/pull/2'},
#      'issue': {'href': 'https://api.github.com/repos/VitorPiovezan/Projeto_GameOn/issues/2'},
#      'comments': {'href': 'https://api.github.com/repos/VitorPiovezan/Projeto_GameOn/issues/2/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/VitorPiovezan/Projeto_GameOn/pulls/2/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/VitorPiovezan/Projeto_GameOn/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/VitorPiovezan/Projeto_GameOn/pulls/2/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/VitorPiovezan/Projeto_GameOn/statuses/edcb623a234b2d948ac2fe1e48f3a0c1ffe5cb56'}},
#     'author_association': 'NONE',
#     'merged': False,
#     'mergeable': None,
#     'rebaseable': None,
#     'mergeable_state': 'unknown',
#     'merged_by': None,
#     'comments': 0,
#     'review_comments': 0,
#     'maintainer_can_modify': False,
#     'commits': 1,
#     'additions': 61,
#     'deletions': 18,
#     'changed_files': 2}},
#   'public': True,
#   'created_at': '2019-12-30T02:48:49Z'},
#  {'id': '11175647294',
#   'type': 'PushEvent',
#   'actor': {'id': 164491,
#    'login': 'zjffdu',
#    'display_login': 'zjffdu',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/zjffdu',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/164491?'},
#   'repo': {'id': 46907161,
#    'name': 'zjffdu/zeppelin',
#    'url': 'https://api.github.com/repos/zjffdu/zeppelin'},
#   'payload': {'push_id': 4445186448,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/ZEPPELIN-4522',
#    'head': '141ba598b83a90951e86730724c66e9fccd1677d',
#    'before': '52b0432f8a0d342ec0973520741cce0ce3b5482c',
#    'commits': [{'sha': '141ba598b83a90951e86730724c66e9fccd1677d',
#      'author': {'email': 'zjffdu@apache.org', 'name': 'Jeff Zhang'},
#      'message': 'fix failed test',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/zjffdu/zeppelin/commits/141ba598b83a90951e86730724c66e9fccd1677d'}]},
#   'public': True,
#   'created_at': '2019-12-30T02:48:49Z'},
#  {'id': '11175647286',
#   'type': 'CreateEvent',
#   'actor': {'id': 49699333,
#    'login': 'dependabot[bot]',
#    'display_login': 'dependabot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dependabot[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/49699333?'},
#   'repo': {'id': 212841595,
#    'name': 'ra79sta/Food-recipe-react-APP',
#    'url': 'https://api.github.com/repos/ra79sta/Food-recipe-react-APP'},
#   'payload': {'ref': 'dependabot/npm_and_yarn/handlebars-4.5.3',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2019-12-30T02:48:49Z'},
#  {'id': '11175647293',
#   'type': 'ForkEvent',
#   'actor': {'id': 13212171,
#    'login': 'winsomexjs',
#    'display_login': 'winsomexjs',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/winsomexjs',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/13212171?'},
#   'repo': {'id': 79779269,
#    'name': 'youzan/vant-weapp',
#    'url': 'https://api.github.com/repos/youzan/vant-weapp'},
#   'payload': {'forkee': {'id': 230835787,
#     'node_id': 'MDEwOlJlcG9zaXRvcnkyMzA4MzU3ODc=',
#     'name': 'vant-weapp',
#     'full_name': 'winsomexjs/vant-weapp',
#     'private': False,
#     'owner': {'login': 'winsomexjs',
#      'id': 13212171,
#      'node_id': 'MDQ6VXNlcjEzMjEyMTcx',
#      'avatar_url': 'https://avatars1.githubusercontent.com/u/13212171?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/winsomexjs',
#      'html_url': 'https://github.com/winsomexjs',
#      'followers_url': 'https://api.github.com/users/winsomexjs/followers',
#      'following_url': 'https://api.github.com/users/winsomexjs/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/winsomexjs/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/winsomexjs/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/winsomexjs/subscriptions',
#      'organizations_url': 'https://api.github.com/users/winsomexjs/orgs',
#      'repos_url': 'https://api.github.com/users/winsomexjs/repos',
#      'events_url': 'https://api.github.com/users/winsomexjs/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/winsomexjs/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'html_url': 'https://github.com/winsomexjs/vant-weapp',
#     'description': '轻量、可靠的小程序 UI 组件库',
#     'fork': True,
#     'url': 'https://api.github.com/repos/winsomexjs/vant-weapp',
#     'forks_url': 'https://api.github.com/repos/winsomexjs/vant-weapp/forks',
#     'keys_url': 'https://api.github.com/repos/winsomexjs/vant-weapp/keys{/key_id}',
#     'collaborators_url': 'https://api.github.com/repos/winsomexjs/vant-weapp/collaborators{/collaborator}',
#     'teams_url': 'https://api.github.com/repos/winsomexjs/vant-weapp/teams',
#     'hooks_url': 'https://api.github.com/repos/winsomexjs/vant-weapp/hooks',
#     'issue_events_url': 'https://api.github.com/repos/winsomexjs/vant-weapp/issues/events{/number}',
#     'events_url': 'https://api.github.com/repos/winsomexjs/vant-weapp/events',
#     'assignees_url': 'https://api.github.com/repos/winsomexjs/vant-weapp/assignees{/user}',
#     'branches_url': 'https://api.github.com/repos/winsomexjs/vant-weapp/branches{/branch}',
#     'tags_url': 'https://api.github.com/repos/winsomexjs/vant-weapp/tags',
#     'blobs_url': 'https://api.github.com/repos/winsomexjs/vant-weapp/git/blobs{/sha}',
#     'git_tags_url': 'https://api.github.com/repos/winsomexjs/vant-weapp/git/tags{/sha}',
#     'git_refs_url': 'https://api.github.com/repos/winsomexjs/vant-weapp/git/refs{/sha}',
#     'trees_url': 'https://api.github.com/repos/winsomexjs/vant-weapp/git/trees{/sha}',
#     'statuses_url': 'https://api.github.com/repos/winsomexjs/vant-weapp/statuses/{sha}',
#     'languages_url': 'https://api.github.com/repos/winsomexjs/vant-weapp/languages',
#     'stargazers_url': 'https://api.github.com/repos/winsomexjs/vant-weapp/stargazers',
#     'contributors_url': 'https://api.github.com/repos/winsomexjs/vant-weapp/contributors',
#     'subscribers_url': 'https://api.github.com/repos/winsomexjs/vant-weapp/subscribers',
#     'subscription_url': 'https://api.github.com/repos/winsomexjs/vant-weapp/subscription',
#     'commits_url': 'https://api.github.com/repos/winsomexjs/vant-weapp/commits{/sha}',
#     'git_commits_url': 'https://api.github.com/repos/winsomexjs/vant-weapp/git/commits{/sha}',
#     'comments_url': 'https://api.github.com/repos/winsomexjs/vant-weapp/comments{/number}',
#     'issue_comment_url': 'https://api.github.com/repos/winsomexjs/vant-weapp/issues/comments{/number}',
#     'contents_url': 'https://api.github.com/repos/winsomexjs/vant-weapp/contents/{+path}',
#     'compare_url': 'https://api.github.com/repos/winsomexjs/vant-weapp/compare/{base}...{head}',
#     'merges_url': 'https://api.github.com/repos/winsomexjs/vant-weapp/merges',
#     'archive_url': 'https://api.github.com/repos/winsomexjs/vant-weapp/{archive_format}{/ref}',
#     'downloads_url': 'https://api.github.com/repos/winsomexjs/vant-weapp/downloads',
#     'issues_url': 'https://api.github.com/repos/winsomexjs/vant-weapp/issues{/number}',
#     'pulls_url': 'https://api.github.com/repos/winsomexjs/vant-weapp/pulls{/number}',
#     'milestones_url': 'https://api.github.com/repos/winsomexjs/vant-weapp/milestones{/number}',
#     'notifications_url': 'https://api.github.com/repos/winsomexjs/vant-weapp/notifications{?since,all,participating}',
#     'labels_url': 'https://api.github.com/repos/winsomexjs/vant-weapp/labels{/name}',
#     'releases_url': 'https://api.github.com/repos/winsomexjs/vant-weapp/releases{/id}',
#     'deployments_url': 'https://api.github.com/repos/winsomexjs/vant-weapp/deployments',
#     'created_at': '2019-12-30T02:48:48Z',
#     'updated_at': '2019-12-30T02:48:47Z',
#     'pushed_at': '2019-12-29T01:30:58Z',
#     'git_url': 'git://github.com/winsomexjs/vant-weapp.git',
#     'ssh_url': 'git@github.com:winsomexjs/vant-weapp.git',
#     'clone_url': 'https://github.com/winsomexjs/vant-weapp.git',
#     'svn_url': 'https://github.com/winsomexjs/vant-weapp',
#     'homepage': 'https://youzan.github.io/vant-weapp',
#     'size': 10003,
#     'stargazers_count': 0,
#     'watchers_count': 0,
#     'language': None,
#     'has_issues': False,
#     'has_projects': True,
#     'has_downloads': True,
#     'has_wiki': True,
#     'has_pages': False,
#     'forks_count': 0,
#     'mirror_url': None,
#     'archived': False,
#     'disabled': False,
#     'open_issues_count': 0,
#     'license': None,
#     'forks': 0,
#     'open_issues': 0,
#     'watchers': 0,
#     'default_branch': 'master',
#     'public': True}},
#   'public': True,
#   'created_at': '2019-12-30T02:48:49Z',
#   'org': {'id': 11404085,
#    'login': 'youzan',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/youzan',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/11404085?'}},
#  {'id': '11175647288',
#   'type': 'CreateEvent',
#   'actor': {'id': 43138936,
#    'login': 'ElMotiloger',
#    'display_login': 'ElMotiloger',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ElMotiloger',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/43138936?'},
#   'repo': {'id': 230835154,
#    'name': 'ElMotiloger/Ai_dog_recognition',
#    'url': 'https://api.github.com/repos/ElMotiloger/Ai_dog_recognition'},
#   'payload': {'ref': 'master',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2019-12-30T02:48:49Z'},
#  {'id': '11175647284',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 49699333,
#    'login': 'dependabot[bot]',
#    'display_login': 'dependabot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dependabot[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/49699333?'},
#   'repo': {'id': 212820265,
#    'name': 'BlueBridgeOne/Commco-P101000-SB-Kilimanjaro',
#    'url': 'https://api.github.com/repos/BlueBridgeOne/Commco-P101000-SB-Kilimanjaro'},
#   'payload': {'action': 'opened',
#    'number': 16,
#    'pull_request': {'url': 'https://api.github.com/repos/BlueBridgeOne/Commco-P101000-SB-Kilimanjaro/pulls/16',
#     'id': 357952004,
#     'node_id': 'MDExOlB1bGxSZXF1ZXN0MzU3OTUyMDA0',
#     'html_url': 'https://github.com/BlueBridgeOne/Commco-P101000-SB-Kilimanjaro/pull/16',
#     'diff_url': 'https://github.com/BlueBridgeOne/Commco-P101000-SB-Kilimanjaro/pull/16.diff',
#     'patch_url': 'https://github.com/BlueBridgeOne/Commco-P101000-SB-Kilimanjaro/pull/16.patch',
#     'issue_url': 'https://api.github.com/repos/BlueBridgeOne/Commco-P101000-SB-Kilimanjaro/issues/16',
#     'number': 16,
#     'state': 'open',
#     'locked': False,
#     'title': 'Bump handlebars from 4.0.10 to 4.5.3 in /Deepak/Source/_Sources/SuiteCommerce Site Builder Premium - Kilimanjaro',
#     'user': {'login': 'dependabot[bot]',
#      'id': 49699333,
#      'node_id': 'MDM6Qm90NDk2OTkzMzM=',
#      'avatar_url': 'https://avatars0.githubusercontent.com/in/29110?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/dependabot%5Bbot%5D',
#      'html_url': 'https://github.com/apps/dependabot',
#      'followers_url': 'https://api.github.com/users/dependabot%5Bbot%5D/followers',
#      'following_url': 'https://api.github.com/users/dependabot%5Bbot%5D/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/dependabot%5Bbot%5D/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/dependabot%5Bbot%5D/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/dependabot%5Bbot%5D/subscriptions',
#      'organizations_url': 'https://api.github.com/users/dependabot%5Bbot%5D/orgs',
#      'repos_url': 'https://api.github.com/users/dependabot%5Bbot%5D/repos',
#      'events_url': 'https://api.github.com/users/dependabot%5Bbot%5D/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/dependabot%5Bbot%5D/received_events',
#      'type': 'Bot',
#      'site_admin': False},
#     'body': 'Bumps [handlebars](https://github.com/wycats/handlebars.js) from 4.0.10 to 4.5.3.\n<details>\n<summary>Changelog</summary>\n\n*Sourced from [handlebars\'s changelog](https://github.com/wycats/handlebars.js/blob/master/release-notes.md).*\n\n> ## v4.5.3 - November 18th, 2019\n> Bugfixes:\n> \n> - fix: add "no-prototype-builtins" eslint-rule and fix all occurences - f7f05d7\n> - fix: add more properties required to be enumerable - 1988878\n> \n> Chores / Build:\n> - fix: use !== 0 instead of != 0 - c02b05f\n> - add chai and dirty-chai and sinon, for cleaner test-assertions and spies, \n>   deprecate old assertion-methods  - 93e284e, 886ba86, 0817dad, 93516a0\n> \n> Security:\n> \n> - The properties `__proto__`, `__defineGetter__`, `__defineSetter__` and `__lookupGetter__` \n>   have been added to the list of "properties that must be enumerable".\n>   If a property by that name is found and not enumerable on its parent, \n>   it will silently evaluate to `undefined`. This is done in both the compiled template and the "lookup"-helper. \n>   This will prevent new Remote-Code-Execution exploits that have been\n>   published recently.\n> \n> Compatibility notes: \n> \n> - Due to the security-fixes. The semantics of the templates using\n>   `__proto__`, `__defineGetter__`, `__defineSetter__` and `__lookupGetter__` in the respect that those expression now return \n>   `undefined` rather than their actual value from the proto.\n> - The semantics have not changed in cases where the properties are  enumerable, as in:\n> \n> ```js\n> {\n>   __proto__: \'some string\'\n> }\n> ```\n> \n> - The change may be breaking in that respect, but we still only \n>   increase the patch-version, because the incompatible use-cases\n>   are not intended, undocumented and far less important than fixing\n>   Remote-Code-Execution exploits on existing systems.\n> \n> \n> \n> [Commits](https://github.com/wycats/handlebars.js/compare/v4.5.2...v4.5.3)\n> \n> ## v4.5.2 - November 13th, 2019\n> # Bugfixes\n> \n> - fix: use String(field) in lookup when checking for "constructor" - d541378\n> - test: add fluent API for testing Handlebars - c2ac79c\n> \n> Compatibility notes:\n> - no incompatibility are to be expected\n></tr></table> ... (truncated)\n</details>\n<details>\n<summary>Commits</summary>\n\n- [`c819c8b`](https://github.com/wycats/handlebars.js/commit/c819c8b533934d2ac18001d7eb27a3205b00c2f3) v4.5.3\n- [`827c9d0`](https://github.com/wycats/handlebars.js/commit/827c9d0747bef7d7f89829779523b6b2dcf3051d) Update release notes\n- [`f7f05d7`](https://github.com/wycats/handlebars.js/commit/f7f05d7558e674856686b62a00cde5758f3b7a08) fix: add "no-prototype-builtins" eslint-rule and fix all occurences\n- [`1988878`](https://github.com/wycats/handlebars.js/commit/198887808780bbef9dba67a8af68ece091d5baa7) fix: add more properties required to be enumerable\n- [`886ba86`](https://github.com/wycats/handlebars.js/commit/886ba86c2f9cc71b7d99b9018fbe2d72a57085cc) test/chore: add chai/expect and sinon to "runtime"-environment\n- [`0817dad`](https://github.com/wycats/handlebars.js/commit/0817dad7e72c51d07f7700547d0c69aa79a4976b) test: add sinon as global variable to eslint in the specs\n- [`93516a0`](https://github.com/wycats/handlebars.js/commit/93516a0b07026ebd23c84fddf270a0c8b570bc59) test: add sinon.js for spies, deprecate current assertions\n- [`93e284e`](https://github.com/wycats/handlebars.js/commit/93e284ed9be1e38c5e6945f15af1ccd689f2ada6) chore: add chai and dirty-chai for better test assertions\n- [`c02b05f`](https://github.com/wycats/handlebars.js/commit/c02b05fa819f46bb66c878bebc6e8006408ebd5c) fix: use !== 0 instead of != 0\n- [`8de121d`](https://github.com/wycats/handlebars.js/commit/8de121d21c88a6ab877e3a0eec9daaac483f3bf0) v4.5.2\n- Additional commits viewable in [compare view](https://github.com/wycats/handlebars.js/compare/v4.0.10...v4.5.3)\n</details>\n<br />\n\n[![Dependabot compatibility score](https://dependabot-badges.githubapp.com/badges/c ...
#     'created_at': '2019-12-30T02:48:48Z',
#     'updated_at': '2019-12-30T02:48:48Z',
#     'closed_at': None,
#     'merged_at': None,
# ...
#      'sha': '3b6da34f7549779c59c2ab033128aa0b3af50d75',
#      'user': {'login': 'rastafasha',
#       'id': 41023438,
#       'node_id': 'MDQ6VXNlcjQxMDIzNDM4',
#       'avatar_url': 'https://avatars2.githubusercontent.com/u/41023438?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/rastafasha',
#       'html_url': 'https://github.com/rastafasha',
#       'followers_url': 'https://api.github.com/users/rastafasha/followers',
#       'following_url': 'https://api.github.com/users/rastafasha/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/rastafasha/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/rastafasha/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/rastafasha/subscriptions',
#       'organizations_url': 'https://api.github.com/users/rastafasha/orgs',
#       'repos_url': 'https://api.github.com/users/rastafasha/repos',
#       'events_url': 'https://api.github.com/users/rastafasha/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/rastafasha/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 212898751,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkyMTI4OTg3NTE=',
#       'name': 'Vali-Frontend-Angular',
#       'full_name': 'rastafasha/Vali-Frontend-Angular',
#       'private': False,
#       'owner': {'login': 'rastafasha',
#        'id': 41023438,
#        'node_id': 'MDQ6VXNlcjQxMDIzNDM4',
#        'avatar_url': 'https://avatars2.githubusercontent.com/u/41023438?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/rastafasha',
#        'html_url': 'https://github.com/rastafasha',
#        'followers_url': 'https://api.github.com/users/rastafasha/followers',
#        'following_url': 'https://api.github.com/users/rastafasha/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/rastafasha/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/rastafasha/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/rastafasha/subscriptions',
#        'organizations_url': 'https://api.github.com/users/rastafasha/orgs',
#        'repos_url': 'https://api.github.com/users/rastafasha/repos',
#        'events_url': 'https://api.github.com/users/rastafasha/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/rastafasha/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/rastafasha/Vali-Frontend-Angular',
#       'description': 'Desarrollo frontend vali en angular 7',
#       'fork': False,
#       'url': 'https://api.github.com/repos/rastafasha/Vali-Frontend-Angular',
#       'forks_url': 'https://api.github.com/repos/rastafasha/Vali-Frontend-Angular/forks',
#       'keys_url': 'https://api.github.com/repos/rastafasha/Vali-Frontend-Angular/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/rastafasha/Vali-Frontend-Angular/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/rastafasha/Vali-Frontend-Angular/teams',
#       'hooks_url': 'https://api.github.com/repos/rastafasha/Vali-Frontend-Angular/hooks',
#       'issue_events_url': 'https://api.github.com/repos/rastafasha/Vali-Frontend-Angular/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/rastafasha/Vali-Frontend-Angular/events',
#       'assignees_url': 'https://api.github.com/repos/rastafasha/Vali-Frontend-Angular/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/rastafasha/Vali-Frontend-Angular/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/rastafasha/Vali-Frontend-Angular/tags',
#       'blobs_url': 'https://api.github.com/repos/rastafasha/Vali-Frontend-Angular/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/rastafasha/Vali-Frontend-Angular/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/rastafasha/Vali-Frontend-Angular/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/rastafasha/Vali-Frontend-Angular/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/rastafasha/Vali-Frontend-Angular/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/rastafasha/Vali-Frontend-Angular/languages',
#       'stargazers_url': 'https://api.github.com/repos/rastafasha/Vali-Frontend-Angular/stargazers',
#       'contributors_url': 'https://api.github.com/repos/rastafasha/Vali-Frontend-Angular/contributors',
#       'subscribers_url': 'https://api.github.com/repos/rastafasha/Vali-Frontend-Angular/subscribers',
#       'subscription_url': 'https://api.github.com/repos/rastafasha/Vali-Frontend-Angular/subscription',
#       'commits_url': 'https://api.github.com/repos/rastafasha/Vali-Frontend-Angular/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/rastafasha/Vali-Frontend-Angular/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/rastafasha/Vali-Frontend-Angular/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/rastafasha/Vali-Frontend-Angular/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/rastafasha/Vali-Frontend-Angular/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/rastafasha/Vali-Frontend-Angular/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/rastafasha/Vali-Frontend-Angular/merges',
#       'archive_url': 'https://api.github.com/repos/rastafasha/Vali-Frontend-Angular/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/rastafasha/Vali-Frontend-Angular/downloads',
#       'issues_url': 'https://api.github.com/repos/rastafasha/Vali-Frontend-Angular/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/rastafasha/Vali-Frontend-Angular/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/rastafasha/Vali-Frontend-Angular/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/rastafasha/Vali-Frontend-Angular/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/rastafasha/Vali-Frontend-Angular/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/rastafasha/Vali-Frontend-Angular/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/rastafasha/Vali-Frontend-Angular/deployments',
#       'created_at': '2019-10-04T20:38:24Z',
#       'updated_at': '2019-11-23T03:44:56Z',
#       'pushed_at': '2019-12-30T02:48:47Z',
#       'git_url': 'git://github.com/rastafasha/Vali-Frontend-Angular.git',
#       'ssh_url': 'git@github.com:rastafasha/Vali-Frontend-Angular.git',
#       'clone_url': 'https://github.com/rastafasha/Vali-Frontend-Angular.git',
#       'svn_url': 'https://github.com/rastafasha/Vali-Frontend-Angular',
#       'homepage': None,
#       'size': 7961,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'TypeScript',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 1,
#       'license': None,
#       'forks': 0,
#       'open_issues': 1,
#       'watchers': 0,
#       'default_branch': 'master'}},
#     'base': {'label': 'rastafasha:master',
#      'ref': 'master',
#      'sha': '2574ef0af3191439a15c4d706094ba50bc551d82',
#      'user': {'login': 'rastafasha',
#       'id': 41023438,
#       'node_id': 'MDQ6VXNlcjQxMDIzNDM4',
#       'avatar_url': 'https://avatars2.githubusercontent.com/u/41023438?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/rastafasha',
#       'html_url': 'https://github.com/rastafasha',
#       'followers_url': 'https://api.github.com/users/rastafasha/followers',
#       'following_url': 'https://api.github.com/users/rastafasha/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/rastafasha/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/rastafasha/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/rastafasha/subscriptions',
#       'organizations_url': 'https://api.github.com/users/rastafasha/orgs',
#       'repos_url': 'https://api.github.com/users/rastafasha/repos',
#       'events_url': 'https://api.github.com/users/rastafasha/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/rastafasha/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 212898751,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkyMTI4OTg3NTE=',
#       'name': 'Vali-Frontend-Angular',
#       'full_name': 'rastafasha/Vali-Frontend-Angular',
#       'private': False,
#       'owner': {'login': 'rastafasha',
#        'id': 41023438,
#        'node_id': 'MDQ6VXNlcjQxMDIzNDM4',
#        'avatar_url': 'https://avatars2.githubusercontent.com/u/41023438?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/rastafasha',
#        'html_url': 'https://github.com/rastafasha',
#        'followers_url': 'https://api.github.com/users/rastafasha/followers',
#        'following_url': 'https://api.github.com/users/rastafasha/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/rastafasha/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/rastafasha/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/rastafasha/subscriptions',
#        'organizations_url': 'https://api.github.com/users/rastafasha/orgs',
#        'repos_url': 'https://api.github.com/users/rastafasha/repos',
#        'events_url': 'https://api.github.com/users/rastafasha/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/rastafasha/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/rastafasha/Vali-Frontend-Angular',
#       'description': 'Desarrollo frontend vali en angular 7',
#       'fork': False,
#       'url': 'https://api.github.com/repos/rastafasha/Vali-Frontend-Angular',
#       'forks_url': 'https://api.github.com/repos/rastafasha/Vali-Frontend-Angular/forks',
#       'keys_url': 'https://api.github.com/repos/rastafasha/Vali-Frontend-Angular/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/rastafasha/Vali-Frontend-Angular/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/rastafasha/Vali-Frontend-Angular/teams',
#       'hooks_url': 'https://api.github.com/repos/rastafasha/Vali-Frontend-Angular/hooks',
#       'issue_events_url': 'https://api.github.com/repos/rastafasha/Vali-Frontend-Angular/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/rastafasha/Vali-Frontend-Angular/events',
#       'assignees_url': 'https://api.github.com/repos/rastafasha/Vali-Frontend-Angular/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/rastafasha/Vali-Frontend-Angular/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/rastafasha/Vali-Frontend-Angular/tags',
#       'blobs_url': 'https://api.github.com/repos/rastafasha/Vali-Frontend-Angular/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/rastafasha/Vali-Frontend-Angular/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/rastafasha/Vali-Frontend-Angular/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/rastafasha/Vali-Frontend-Angular/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/rastafasha/Vali-Frontend-Angular/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/rastafasha/Vali-Frontend-Angular/languages',
#       'stargazers_url': 'https://api.github.com/repos/rastafasha/Vali-Frontend-Angular/stargazers',
#       'contributors_url': 'https://api.github.com/repos/rastafasha/Vali-Frontend-Angular/contributors',
#       'subscribers_url': 'https://api.github.com/repos/rastafasha/Vali-Frontend-Angular/subscribers',
#       'subscription_url': 'https://api.github.com/repos/rastafasha/Vali-Frontend-Angular/subscription',
#       'commits_url': 'https://api.github.com/repos/rastafasha/Vali-Frontend-Angular/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/rastafasha/Vali-Frontend-Angular/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/rastafasha/Vali-Frontend-Angular/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/rastafasha/Vali-Frontend-Angular/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/rastafasha/Vali-Frontend-Angular/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/rastafasha/Vali-Frontend-Angular/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/rastafasha/Vali-Frontend-Angular/merges',
#       'archive_url': 'https://api.github.com/repos/rastafasha/Vali-Frontend-Angular/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/rastafasha/Vali-Frontend-Angular/downloads',
#       'issues_url': 'https://api.github.com/repos/rastafasha/Vali-Frontend-Angular/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/rastafasha/Vali-Frontend-Angular/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/rastafasha/Vali-Frontend-Angular/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/rastafasha/Vali-Frontend-Angular/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/rastafasha/Vali-Frontend-Angular/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/rastafasha/Vali-Frontend-Angular/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/rastafasha/Vali-Frontend-Angular/deployments',
#       'created_at': '2019-10-04T20:38:24Z',
#       'updated_at': '2019-11-23T03:44:56Z',
#       'pushed_at': '2019-12-30T02:48:47Z',
#       'git_url': 'git://github.com/rastafasha/Vali-Frontend-Angular.git',
#       'ssh_url': 'git@github.com:rastafasha/Vali-Frontend-Angular.git',
#       'clone_url': 'https://github.com/rastafasha/Vali-Frontend-Angular.git',
#       'svn_url': 'https://github.com/rastafasha/Vali-Frontend-Angular',
#       'homepage': None,
#       'size': 7961,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'TypeScript',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 1,
#       'license': None,
#       'forks': 0,
#       'open_issues': 1,
#       'watchers': 0,
#       'default_branch': 'master'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/rastafasha/Vali-Frontend-Angular/pulls/1'},
#      'html': {'href': 'https://github.com/rastafasha/Vali-Frontend-Angular/pull/1'},
#      'issue': {'href': 'https://api.github.com/repos/rastafasha/Vali-Frontend-Angular/issues/1'},
#      'comments': {'href': 'https://api.github.com/repos/rastafasha/Vali-Frontend-Angular/issues/1/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/rastafasha/Vali-Frontend-Angular/pulls/1/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/rastafasha/Vali-Frontend-Angular/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/rastafasha/Vali-Frontend-Angular/pulls/1/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/rastafasha/Vali-Frontend-Angular/statuses/3b6da34f7549779c59c2ab033128aa0b3af50d75'}},
#     'author_association': 'NONE',
#     'merged': False,
#     'mergeable': None,
#     'rebaseable': None,
#     'mergeable_state': 'unknown',
#     'merged_by': None,
#     'comments': 0,
#     'review_comments': 0,
#     'maintainer_can_modify': False,
#     'commits': 1,
#     'additions': 3,
#     'deletions': 3,
#     'changed_files': 1}},
#   'public': True,
#   'created_at': '2019-12-30T02:48:48Z'}]

# %% [markdown]
# ### 自行尋找一個合適的 API 接口做練習，並且查看其回傳內容
#
# * https://cat-fact.herokuapp.com/facts (來源：https://alexwohlbruck.github.io/cat-facts/)
# * http://odata.wra.gov.tw/v4/RealtimeWaterLevel (來源：https://data.gov.tw/dataset/25768)

# %%
import requests
import json
f=requests.get('http://odata.wra.gov.tw/v4/RealtimeWaterLevel')
f.text
# Out:
# '{"@odata.context": "http://odata.wra.gov.tw/v4/$metadata#RealtimeWaterLevel",\n"@odata.count": 100,\n"value": [{"RecordTime": "Dec 11, 2019 2:50:00 PM","StationIdentifier": "2200H029","WaterLevel": 145.15},{"RecordTime": "Dec 11, 2019 2:50:00 PM","StationIdentifier": "1730H070","WaterLevel": 226.25},{"RecordTime": "Dec 11, 2019 2:50:00 PM","StationIdentifier": "1580H021","WaterLevel": 1.28},{"RecordTime": "Dec 11, 2019 2:50:00 PM","StationIdentifier": "1580H017","WaterLevel": 25.73},{"RecordTime": "Dec 11, 2019 2:50:00 PM","StationIdentifier": "2560H019","WaterLevel": 4.48},{"RecordTime": "Dec 11, 2019 2:50:00 PM","StationIdentifier": "1580H001","WaterLevel": 224.21},{"RecordTime": "Dec 11, 2019 2:50:00 PM","StationIdentifier": "1730H075","WaterLevel": 92.83},{"RecordTime": "Dec 11, 2019 2:50:00 PM","StationIdentifier": "2420H036","WaterLevel": 164.37},{"RecordTime": "Dec 11, 2019 2:50:00 PM","StationIdentifier": "2500H003","WaterLevel": 32.2},{"RecordTime": "Dec 11, 2019 2:50:00 PM","StationIdentifier": "1730H066","WaterLevel": 138.73},{"RecordTime": "Dec 11, 2019 2:50:00 PM","StationIdentifier": "1730H077","WaterLevel": 740.49},{"RecordTime": "Dec 11, 2019 2:50:00 PM","StationIdentifier": "1550H014","WaterLevel": 26.75},{"RecordTime": "Dec 11, 2019 2:50:00 PM","StationIdentifier": "1670H004","WaterLevel": 2.98},{"RecordTime": "Dec 11, 2019 2:50:00 PM","StationIdentifier": "2420H019","WaterLevel": 109.97},{"RecordTime": "Dec 11, 2019 2:50:00 PM","StationIdentifier": "1650H012","WaterLevel": 0.7},{"RecordTime": "Dec 11, 2019 2:50:00 PM","StationIdentifier": "1730H061","WaterLevel": 266.23},{"RecordTime": "Dec 11, 2019 2:50:00 PM","StationIdentifier": "1730H072","WaterLevel": 248.86},{"RecordTime": "Dec 11, 2019 2:50:00 PM","StationIdentifier": "1540H039","WaterLevel": 38.99},{"RecordTime": "Dec 11, 2019 2:50:00 PM","StationIdentifier": "1660H012","WaterLevel": 0.14},{"RecordTime": "Dec 11, 2019 2:50:00 PM","StationIdentifier": "2370H025","WaterLevel": 261.61},{"RecordTime": "Dec 11, 2019 2:50:00 PM","StationIdentifier": "1650H009","WaterLevel": 0.1},{"RecordTime": "Dec 11, 2019 2:50:00 PM","StationIdentifier": "1730H057","WaterLevel": 43.48},{"RecordTime": "Dec 11, 2019 2:50:00 PM","StationIdentifier": "1730H068","WaterLevel": 10.14},{"RecordTime": "Dec 11, 2019 2:50:00 PM","StationIdentifier": "1540H037","WaterLevel": 32.01},{"RecordTime": "Dec 11, 2019 2:50:00 PM","StationIdentifier": "1650H015","WaterLevel": 0.05},{"RecordTime": "Dec 11, 2019 2:50:00 PM","StationIdentifier": "2370H018","WaterLevel": 124.1},{"RecordTime": "Dec 11, 2019 2:50:00 PM","StationIdentifier": "1630H036","WaterLevel": 65.83},{"RecordTime": "Dec 11, 2019 2:50:00 PM","StationIdentifier": "1660H009","WaterLevel": 4.85},{"RecordTime": "Dec 11, 2019 2:50:00 PM","StationIdentifier": "1730H043","WaterLevel": 23.04},{"RecordTime": "Dec 11, 2019 2:50:00 PM","StationIdentifier": "2420H043","WaterLevel": 79.32},{"RecordTime": "Dec 11, 2019 2:50:00 PM","StationIdentifier": "1540H033","WaterLevel": 23.4},{"RecordTime": "Dec 11, 2019 2:50:00 PM","StationIdentifier": "1650H010","WaterLevel": 0.19},{"RecordTime": "Dec 11, 2019 2:20:00 PM","StationIdentifier": "1630H030","WaterLevel": 1.57},{"RecordTime": "Dec 11, 2019 2:20:00 PM","StationIdentifier": "1630H032","WaterLevel": 0.13},{"RecordTime": "Dec 11, 2019 2:50:00 PM","StationIdentifier": "1650H013","WaterLevel": 5.62},{"RecordTime": "Dec 11, 2019 2:50:00 PM","StationIdentifier": "1680H005","WaterLevel": 0.11},{"RecordTime": "Dec 11, 2019 2:50:00 PM","StationIdentifier": "2200H026","WaterLevel": 106.73},{"RecordTime": "Dec 11, 2019 2:50:00 PM","StationIdentifier": "1350H031","WaterLevel": -0.15},{"RecordTime": "Dec 11, 2019 2:50:00 PM","StationIdentifier": "1630H040","WaterLevel": 1.76},{"RecordTime": "Dec 11, 2019 2:50:00 PM","StationIdentifier": "1630H018","WaterLevel": 10.01},{"RecordTime": "Dec 11, 2019 2:20:00 PM","StationIdentifier": "1630H027","WaterLevel": 26.14},{"RecordTime": "Dec 11, 2019 2:50:00 PM", ...

# %%
json.loads(f.text)
# Out:
# {'@odata.context': 'http://odata.wra.gov.tw/v4/$metadata#RealtimeWaterLevel',
#  '@odata.count': 100,
#  'value': [{'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '2200H029',
#    'WaterLevel': 145.15},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1730H070',
#    'WaterLevel': 226.25},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1580H021',
#    'WaterLevel': 1.28},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1580H017',
#    'WaterLevel': 25.73},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '2560H019',
#    'WaterLevel': 4.48},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1580H001',
#    'WaterLevel': 224.21},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1730H075',
#    'WaterLevel': 92.83},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '2420H036',
#    'WaterLevel': 164.37},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '2500H003',
#    'WaterLevel': 32.2},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1730H066',
#    'WaterLevel': 138.73},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1730H077',
#    'WaterLevel': 740.49},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1550H014',
#    'WaterLevel': 26.75},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1670H004',
#    'WaterLevel': 2.98},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '2420H019',
#    'WaterLevel': 109.97},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1650H012',
#    'WaterLevel': 0.7},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1730H061',
#    'WaterLevel': 266.23},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1730H072',
#    'WaterLevel': 248.86},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1540H039',
#    'WaterLevel': 38.99},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1660H012',
#    'WaterLevel': 0.14},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '2370H025',
#    'WaterLevel': 261.61},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1650H009',
#    'WaterLevel': 0.1},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1730H057',
#    'WaterLevel': 43.48},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1730H068',
#    'WaterLevel': 10.14},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1540H037',
#    'WaterLevel': 32.01},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1650H015',
#    'WaterLevel': 0.05},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '2370H018',
#    'WaterLevel': 124.1},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1630H036',
#    'WaterLevel': 65.83},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1660H009',
#    'WaterLevel': 4.85},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1730H043',
#    'WaterLevel': 23.04},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '2420H043',
#    'WaterLevel': 79.32},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1540H033',
#    'WaterLevel': 23.4},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1650H010',
#    'WaterLevel': 0.19},
#   {'RecordTime': 'Dec 11, 2019 2:20:00 PM',
#    'StationIdentifier': '1630H030',
#    'WaterLevel': 1.57},
#   {'RecordTime': 'Dec 11, 2019 2:20:00 PM',
#    'StationIdentifier': '1630H032',
#    'WaterLevel': 0.13},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1650H013',
#    'WaterLevel': 5.62},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1680H005',
#    'WaterLevel': 0.11},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '2200H026',
#    'WaterLevel': 106.73},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1350H031',
#    'WaterLevel': -0.15},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1630H040',
#    'WaterLevel': 1.76},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1630H018',
#    'WaterLevel': 10.01},
#   {'RecordTime': 'Dec 11, 2019 2:20:00 PM',
#    'StationIdentifier': '1630H027',
#    'WaterLevel': 26.14},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1540H032',
#    'WaterLevel': 20.45},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1550H012',
#    'WaterLevel': 0.54},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1630H023',
#    'WaterLevel': 0.03},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1350H029',
#    'WaterLevel': 175.97},
#   {'RecordTime': 'Dec 11, 2019 2:20:00 PM',
#    'StationIdentifier': '1630H034',
#    'WaterLevel': 278.47},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1590H016',
#    'WaterLevel': 11.27},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1630H024',
#    'WaterLevel': 69.07},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1540H029',
#    'WaterLevel': 13.13},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1540H030',
#    'WaterLevel': 27.2},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1630H005',
#    'WaterLevel': 39.76},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1350H027',
#    'WaterLevel': 145.89},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1510H082',
#    'WaterLevel': 752.39},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1580H022',
#    'WaterLevel': 0.16},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1430H054',
#    'WaterLevel': 48.29},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1510H084',
#    'WaterLevel': 145.06},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1540H009',
#    'WaterLevel': 0.59},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1590H013',
#    'WaterLevel': 20.76},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1510H080',
#    'WaterLevel': 1068.94},
#   {'RecordTime': 'Dec 11, 2019 9:50:00 AM',
#    'StationIdentifier': '1510H058',
#    'WaterLevel': 12.13},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1430H037',
#    'WaterLevel': 380.46},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1430H051',
#    'WaterLevel': 95.66},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1350H024',
#    'WaterLevel': 259.67},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1520H008',
#    'WaterLevel': 78.22},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1580H018',
#    'WaterLevel': 21.23},
#   {'RecordTime': 'Dec 11, 2019 9:50:00 AM',
#    'StationIdentifier': '1510H079',
#    'WaterLevel': 187.7},
#   {'RecordTime': 'Dec 11, 2019 9:50:00 AM',
#    'StationIdentifier': '1510H049',
#    'WaterLevel': 470.82},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1430H029',
#    'WaterLevel': 50.6},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1430H047',
#    'WaterLevel': 72.35},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1350H020',
#    'WaterLevel': 220.79},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1510H086',
#    'WaterLevel': 317.97},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1580H008',
#    'WaterLevel': 19.39},
#   {'RecordTime': 'Dec 11, 2019 9:50:00 AM',
#    'StationIdentifier': '1510H071',
#    'WaterLevel': 20.5},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1430H056',
#    'WaterLevel': 79.83},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1420H057',
#    'WaterLevel': 639.41},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1420H058',
#    'WaterLevel': 440.47},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1350H016',
#    'WaterLevel': 97.9},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1550H017',
#    'WaterLevel': 15.74},
#   {'RecordTime': 'Dec 11, 2019 9:50:00 AM',
#    'StationIdentifier': '1510H075',
#    'WaterLevel': 346.5},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1430H045',
#    'WaterLevel': 91.76},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1430H058',
#    'WaterLevel': 83.01},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1400H015',
#    'WaterLevel': 622.43},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1420H055',
#    'WaterLevel': 318.68},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1340H015',
#    'WaterLevel': 50.08},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1420H054',
#    'WaterLevel': 704.2},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1350H018',
#    'WaterLevel': 282.05},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1430H040',
#    'WaterLevel': 19.29},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1340H014',
#    'WaterLevel': 0.37},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1400H009',
#    'WaterLevel': 191.55},
#   {'RecordTime': 'Dec 11, 2019 2:55:00 PM',
#    'StationIdentifier': '1140H106',
#    'WaterLevel': 49.11},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '2370H017',
#    'WaterLevel': 58.49},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1420H049',
#    'WaterLevel': 54.19},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1350H001',
#    'WaterLevel': 169.81},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1300H022',
#    'WaterLevel': -1.01},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1340H011',
#    'WaterLevel': 7.38},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1140H108',
#    'WaterLevel': 12.12},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1140H099',
#    'WaterLevel': 263.49},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1850H005',
#    'WaterLevel': 22.09},
#   {'RecordTime': 'Dec 11, 2019 2:40:00 PM',
#    'StationIdentifier': '1400H019',
#    'WaterLevel': 310.14},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1290H002',
#    'WaterLevel': 41}],
#  '@odata.nextLink': 'http://odata.wra.gov.tw/v4/RealtimeWaterLevel?$skip=100&$top=100'}
